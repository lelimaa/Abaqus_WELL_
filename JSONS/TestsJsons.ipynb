# %%
import json 
json_file_path = r'C:\Users\hidalgo\Documents\GitHub\Abaqus_WELL_\wellClosure_axi.json'

config_data = json.load(open(json_file_path, 'r'))

# %%
# print(config_data.keys())

def get_pipe_geometry(data):
    for phase_id, phase_vals in list(data["Phases"].items()):
        pipe_name = phase_vals["Casing"][0]["Tubular"]
        pipe = data["Tubulars"][pipe_name]
        print(pipe)

get_pipe_geometry(config_data)
# Out:
# {'OD': 30.0, 'Thickness': 0.5, 'MinThickness': 90.0, 'Ovality': 0.6, 'Material': 'X56'}
# {'OD': 20.0, 'Thickness': 0.812, 'MinThickness': 87.5, 'Ovality': 0.6, 'Material': 'K55'}
# {'OD': 9.625, 'Thickness': 0.545, 'MinThickness': 87.5, 'Ovality': 0.6, 'Material': 'VM110'}
# {'OD': 14.0, 'Thickness': 0.562, 'MinThickness': 87.5, 'Ovality': 0.6, 'Material': 'P110'}
